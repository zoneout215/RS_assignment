# %%
import os
import pandas as pd
import numpy as np
from tqdm  import tqdm
import pickle
import re
import glob

# %% [markdown]
# # Data preparation

# %%
# Set the directory path where the pickle files are located
directory_path = os.getcwd() + '/ABC'

# Get a list of all the pickle files in the directory
pickle_files = [os.path.join(directory_path, f) for f in os.listdir(directory_path) if f.endswith('.pkl') and f.startswith('full') == False ]

# Load and concatenate the data from each file
# create the empty dataframe with 13 columns

concatenated_data = []
for file in tqdm(pickle_files):
    with open(file, 'rb') as f:
        staged_data = pickle.load(f)
        concatenated_data.append(staged_data)

data = pd.concat(concatenated_data, ignore_index = True, axis=0)
# adding id

data
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 90.91it/s]
#                category                          title  \
# 0                  Arts               Bangarra's World
# 1                  Arts                  Going Country
# 2                  Arts          Mission Songs Project
# 3                  Arts  The Story of Film: An Odyssey
# 4                  Arts                     Ballet Now
# ...                 ...                            ...
# 15176  Panel Discussion                            Q+A
# 15177  Panel Discussion                   One Plus One
# 15178  Panel Discussion                            Q+A
# 15179  Panel Discussion            Would I Lie To You?
# 15180  Panel Discussion                            Q+A
#
#                               series  \
# 0                   Bangarra's World
# 1                      Going Country
# 2              Mission Songs Project
# 3      The Story of Film: An Odyssey
# 4                      No data found
# ...                              ...
# 15176                            Q+A
# 15177                   One Plus One
# 15178                            Q+A
# 15179            Would I Lie To You?
# 15180                            Q+A
#
#                                             episode_name  \
# 0                           Return to Country (Yirrkala)
# 1                                     Series 1 Episode 1
# 2                                                Surrare
# 3                              Episode 5 Post-War Cinema
# 4                                             Ballet Now
# ...                                                  ...
# 15176                                     Budget Special
# 15177                            Series 2019 Murray Cook
# 15178  The Vaccine, the Church, and the State of Poli...
# 15179              Series 13 Episode 11 More Unseen Bits
# 15180      Boats, Boys Clubs and Businesses on the Brink
#
#                                              description  \
# 0      Join the dancers and creatives during Bangarra...
# 1      Justine Clarke takes a road trip into the hear...
# 2      Jessie Lloyd's Mission Songs Project revives s...
# 3      A worldwide guided tour of the greatest movies...
# 4      This film captures the creative process behind...
# ...                                                  ...
# 15176  Q+A is back to get more of the answers to your...
# 15177  Some of your favourite ABC presenters bring yo...
# 15178  Q+A is back to get more of the answers to your...
# 15179  Rob Brydon is back in the host's chair for ano...
# 15180  Q+A is back to get more of the answers to your...
#
#                                             description2  \
# 0      In Yirrkala, Northeast Arnhem Land, Bangarra s...
# 1      Justine Clarke connects with some of Australia...
# 2      A song from the Torres Strait Islands, 'Surrar...
# 3      1939-1952 The trauma of war led to more daring...
# 4      This film captures the creative process behind...
# ...                                                  ...
# 15176  David Speers is joined by Barnaby Joyce, Jim C...
# 15177  Seven years ago, Murray Cook hung up his red s...
# 15178  The Government's "women's ministry" meets for ...
# 15179  More unseen clips from this series of Would I ...
# 15180  Guest host David Speers and the panel check th...
#
#                                                     tags  \
# 0      [ABC TV, ABC TV Plus, INDIGENOUS, ARTS & CULTU...
# 1      [ABC TV, DOCUMENTARY, ARTS & CULTURE, LIFESTYL...
# 2      [ABC TV, DOCUMENTARY, ARTS & CULTURE, INDIGENOUS]
# 3      [ABC TV, ABC TV Plus, ARTS & CULTURE, DOCUMENT...
# 4      [ABC TV Plus, DOCUMENTARY, ARTS & CULTURE, FAM...
# ...                                                  ...
# 15176             [ABC TV, ABC NEWS, PANEL & DISCUSSION]
# 15177       [ABC TV, ARTS & CULTURE, PANEL & DISCUSSION]
# 15178             [ABC TV, ABC NEWS, PANEL & DISCUSSION]
# 15179          [ABC TV Plus, COMEDY, PANEL & DISCUSSION]
# 15180             [ABC TV, ABC NEWS, PANEL & DISCUSSION]
#
#                                                    image  \
# 0      https://cdn.iview.abc.net.au/thumbs/i/ar/AR194...
# 1      https://cdn.iview.abc.net.au/thumbs/i/ac/AC201...
# 2      https://cdn.iview.abc.net.au/thumbs/i/ip/IP206...
# 3      https://cdn.iview.abc.net.au/thumbs/i/zw/ZW286...
# 4      https://cdn.iview.abc.net.au/thumbs/i/zw/ZW269...
# ...                                                  ...
# 15176  https://cdn.iview.abc.net.au/thumbs/i/nc/NC220...
# 15177  https://cdn.iview.abc.net.au/thumbs/i/nc/NC191...
# 15178  https://cdn.iview.abc.net.au/thumbs/i/nc/NC210...
# 15179  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW213...
# 15180  https://cdn.iview.abc.net.au/thumbs/i/nc/NC210...
#
#                                                  more  \
# 0                   Director Nel Minchin, Wayne Blair
# 1                                 Host Justine Clarke
# 2                           No more information found
# 3                                   Host Mark Cousins
# 4                           No more information found
# ...                                               ...
# 15176  Host Virginia Trioli, David Speers, Stan Grant
# 15177                       No more information found
# 15178  Host Virginia Trioli, David Speers, Stan Grant
# 15179                                 Host Rob Brydon
# 15180  Host Virginia Trioli, David Speers, Stan Grant
#
#                                                    tags2     publication_date  \
# 0      [abc1, abc2, indigenous, abcarts, arts, docs, ...  2021-07-07 22:00:00
# 1      [abc1, docs, arts, factual, lifestyle, country...  2021-11-02 20:30:14
# 2      [abc1, docs, factual, arts, indigenous, music,...  2020-11-07 07:00:00
# 3      [abc1, abc2, arts, abcarts, docs, movies, retr...  2021-06-11 07:00:00
# 4      [abc2, docs, factual, arts, ballet, dance, cul...  2021-06-30 21:59:27
# ...                                                  ...                  ...
# 15176  [abc1, news, panel, current-affairs, politics,...  2022-03-31 21:39:55
# 15177  [abc1, news24, arts, panel, talks, people, int...  2019-03-15 13:30:00
# 15178  [abc1, news, panel, current-affairs, politics,...  2021-04-08 21:31:57
# 15179  [abc2, uk, comedy, panel, entertainment, cult-...  2022-03-29 20:29:24
# 15180  [abc1, news, panel, current-affairs, politics,...  2021-06-17 21:33:13
#
#               rating duration_sec
# 0                  G          626
# 1                 PG         3244
# 2                  G          313
# 3                  M         3728
# 4                  M         3555
# ...              ...          ...
# 15176  No data found         3665
# 15177  No data found         1680
# 15178  No data found         3443
# 15179             PG         1725
# 15180  No data found         3738
#
# [15181 rows x 13 columns]

# %%
duplicate_filter = list(data.columns)

#duplicate_filter.remove('id')
duplicate_filter.remove('image')
duplicate_filter.remove('tags')
duplicate_filter.remove('tags2')
duplicate_filter.remove('category')

data.drop_duplicates(subset = duplicate_filter, inplace = True)

data
# Out:
#                category                                              title  \
# 0                  Arts                                   Bangarra's World
# 1                  Arts                                      Going Country
# 2                  Arts                              Mission Songs Project
# 3                  Arts                      The Story of Film: An Odyssey
# 4                  Arts                                         Ballet Now
# ...                 ...                                                ...
# 15158  Panel Discussion                                 You Can't Ask That
# 15159  Panel Discussion                                        Gruen Pitch
# 15168  Panel Discussion                                                 QI
# 15172  Panel Discussion  You Can't Ask That (Simplified Chinese Subtitles)
# 15174  Panel Discussion  You Can't Ask That (Simplified Chinese Subtitles)
#
#                                                   series  \
# 0                                       Bangarra's World
# 1                                          Going Country
# 2                                  Mission Songs Project
# 3                          The Story of Film: An Odyssey
# 4                                          No data found
# ...                                                  ...
# 15158                                 You Can't Ask That
# 15159                                        Gruen Pitch
# 15168                                                 QI
# 15172  You Can't Ask That (Simplified Chinese Subtitles)
# 15174  You Can't Ask That (Simplified Chinese Subtitles)
#
#                          episode_name  \
# 0        Return to Country (Yirrkala)
# 1                  Series 1 Episode 1
# 2                             Surrare
# 3           Episode 5 Post-War Cinema
# 4                          Ballet Now
# ...                               ...
# 15158                Series 1 Muslims
# 15159             Series 12 Episode 1
# 15168  Series 13 Ladies And Gentlemen
# 15172               Series 2 Homeless
# 15174          Series 2 Down Syndrome
#
#                                              description  \
# 0      Join the dancers and creatives during Bangarra...
# 1      Justine Clarke takes a road trip into the hear...
# 2      Jessie Lloyd's Mission Songs Project revives s...
# 3      A worldwide guided tour of the greatest movies...
# 4      This film captures the creative process behind...
# ...                                                  ...
# 15158  Asking the most outrageous and uncomfortable q...
# 15159  The Pitch take us into the thinking of the peo...
# 15168  Sandi Toksvig hosts the return of the quiz wit...
# 15172  Asking the most outrageous and uncomfortable q...
# 15174  Asking the most outrageous and uncomfortable q...
#
#                                             description2  \
# 0      In Yirrkala, Northeast Arnhem Land, Bangarra s...
# 1      Justine Clarke connects with some of Australia...
# 2      A song from the Torres Strait Islands, 'Surrar...
# 3      1939-1952 The trauma of war led to more daring...
# 4      This film captures the creative process behind...
# ...                                                  ...
# 15158  Muslims answer the questions Australians wante...
# 15159  This week, The Pitch is to either love or ditc...
# 15168  Stephen Fry hosts the quiz show in which the a...
# 15172  You Can't Ask That asks homeless people the aw...
# 15174  You Can't Ask That asks people with Down syndr...
#
#                                                     tags  \
# 0      [ABC TV, ABC TV Plus, INDIGENOUS, ARTS & CULTU...
# 1      [ABC TV, DOCUMENTARY, ARTS & CULTURE, LIFESTYL...
# 2      [ABC TV, DOCUMENTARY, ARTS & CULTURE, INDIGENOUS]
# 3      [ABC TV, ABC TV Plus, ARTS & CULTURE, DOCUMENT...
# 4      [ABC TV Plus, DOCUMENTARY, ARTS & CULTURE, FAM...
# ...                                                  ...
# 15158                       [ABC TV, PANEL & DISCUSSION]
# 15159               [ABC TV, COMEDY, PANEL & DISCUSSION]
# 15168                       [ABC TV, PANEL & DISCUSSION]
# 15172                                           [ABC TV]
# 15174                                           [ABC TV]
#
#                                                    image  \
# 0      https://cdn.iview.abc.net.au/thumbs/i/ar/AR194...
# 1      https://cdn.iview.abc.net.au/thumbs/i/ac/AC201...
# 2      https://cdn.iview.abc.net.au/thumbs/i/ip/IP206...
# 3      https://cdn.iview.abc.net.au/thumbs/i/zw/ZW286...
# 4      https://cdn.iview.abc.net.au/thumbs/i/zw/ZW269...
# ...                                                  ...
# 15158  https://cdn.iview.abc.net.au/thumbs/i/le/LE151...
# 15159  https://cdn.iview.abc.net.au/thumbs/i/lr/LR202...
# 15168  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW016...
# 15172  https://cdn.iview.abc.net.au/thumbs/i/iv/IV180...
# 15174  https://cdn.iview.abc.net.au/thumbs/i/iv/IV180...
#
#                                     more  \
# 0      Director Nel Minchin, Wayne Blair
# 1                    Host Justine Clarke
# 2              No more information found
# 3                      Host Mark Cousins
# 4              No more information found
# ...                                  ...
# 15158          No more information found
# 15159                  Host Wil Anderson
# 15168                 Host Sandi Toksvig
# 15172          No more information found
# 15174          No more information found
#
#                                                    tags2     publication_date  \
# 0      [abc1, abc2, indigenous, abcarts, arts, docs, ...  2021-07-07 22:00:00
# 1      [abc1, docs, arts, factual, lifestyle, country...  2021-11-02 20:30:14
# 2      [abc1, docs, factual, arts, indigenous, music,...  2020-11-07 07:00:00
# 3      [abc1, abc2, arts, abcarts, docs, movies, retr...  2021-06-11 07:00:00
# 4      [abc2, docs, factual, arts, ballet, dance, cul...  2021-06-30 21:59:27
# ...                                                  ...                  ...
# 15158  [abc1, panel, entertainment, factual, people, ...  2016-08-03 21:44:00
# 15159  [abc1, aussie, comedy, entertainment, panel, g...  2020-10-16 21:15:00
# 15168  [abc1, uk, panel, entertainment, cult-favourit...  2022-03-19 20:30:19
# 15172                                       [docs, abc1]  2018-02-16 05:30:00
# 15174                                       [docs, abc1]  2018-02-16 05:30:00
#
#       rating duration_sec
# 0          G          626
# 1         PG         3244
# 2          G          313
# 3          M         3728
# 4          M         3555
# ...      ...          ...
# 15158     PG         1280
# 15159      G          242
# 15168     PG         1769
# 15172      M         1695
# 15174      M         1695
#
# [11537 rows x 13 columns]

# %%
data['id'] = data.index
cols = data.columns.tolist()
cols = cols[-1:] + cols[:-1]
data = data[cols]

# %%
# clarifying naming, defining missings


data.rename({'more':'directors_actors'}, axis = 1, inplace = True)
data.replace(['No data found', 'No more information found', 
              'No title found', 'No tags found', 'No image found', 'No description found'], np.nan, inplace = True)

data['directors_actors'] = data['directors_actors'].apply(str).apply(lambda x : x.split(', ') if x != 'nan' else [])

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11537 entries, 0 to 15174
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                11537 non-null  int64
#  1   category          11537 non-null  object
#  2   title             11536 non-null  object
#  3   series            11138 non-null  object
#  4   episode_name      11530 non-null  object
#  5   description       11536 non-null  object
#  6   description2      11533 non-null  object
#  7   tags              11536 non-null  object
#  8   image             11536 non-null  object
#  9   directors_actors  11537 non-null  object
#  10  tags2             11533 non-null  object
#  11  publication_date  11533 non-null  object
#  12  rating            10244 non-null  object
#  13  duration_sec      11532 non-null  float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 1.3+ MB

# %%
# clarifying naming, defining missings


data.rename({'more':'directors_actors'}, axis = 1, inplace = True)
data.replace(['No data found', 'No more information found', 
              'No title found', 'No tags found', 'No image found', 'No description found'], np.nan, inplace = True)

data['directors_actors'] = data['directors_actors'].apply(str).apply(lambda x : x.split(', ') if x != 'nan' else [])

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11537 entries, 0 to 15174
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                11537 non-null  int64
#  1   category          11537 non-null  object
#  2   title             11536 non-null  object
#  3   series            11138 non-null  object
#  4   episode_name      11530 non-null  object
#  5   description       11536 non-null  object
#  6   description2      11533 non-null  object
#  7   tags              11536 non-null  object
#  8   image             11536 non-null  object
#  9   directors_actors  11537 non-null  object
#  10  tags2             11533 non-null  object
#  11  publication_date  11533 non-null  object
#  12  rating            10244 non-null  object
#  13  duration_sec      11532 non-null  float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 1.3+ MB

# %%
cols = list(data.columns)
# dropping nans where it is necessary
unwanted = ['directors_actors', 'rating', 'series', 'directors_actors']
cols = [x for x in cols if x not in unwanted]

clean = data.dropna(subset = cols)
clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11529 entries, 0 to 15174
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                11529 non-null  int64
#  1   category          11529 non-null  object
#  2   title             11529 non-null  object
#  3   series            11134 non-null  object
#  4   episode_name      11529 non-null  object
#  5   description       11529 non-null  object
#  6   description2      11529 non-null  object
#  7   tags              11529 non-null  object
#  8   image             11529 non-null  object
#  9   directors_actors  11529 non-null  object
#  10  tags2             11529 non-null  object
#  11  publication_date  11529 non-null  object
#  12  rating            10242 non-null  object
#  13  duration_sec      11529 non-null  float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 1.3+ MB

# %% [markdown]
# # Creating special columns for episodes

# %%
seasons = []
eps = []
ep_descs = []

for index, row in clean.iterrows():
    i = index
    txt = row.episode_name
    try:
        season = re.findall('Series [0-9]{1,2}', txt)[0]
        season = re.findall('[0-9]+', season)[0]
        seasons.append(season)
    except:
        seasons.append(np.nan)
    try: 
        ep = re.findall('Episode [0-9]{1,2}', txt)[0]
        ep = re.findall('[0-9]+', ep)[0]
        eps.append(ep)
    except:
        eps.append('')
    desc = re.sub('[0-9]+', '', txt)
    desc = desc.replace('Series', '')
    desc = desc.replace('Episode', '')
    ep_descs.append(desc)

clean = clean.assign(season=seasons, episode=eps, episode_title=ep_descs)
clean.head(3)
# Out:
#    id category                  title                 series  \
# 0   0     Arts       Bangarra's World       Bangarra's World
# 1   1     Arts          Going Country          Going Country
# 2   2     Arts  Mission Songs Project  Mission Songs Project
#
#                    episode_name  \
# 0  Return to Country (Yirrkala)
# 1            Series 1 Episode 1
# 2                       Surrare
#
#                                          description  \
# 0  Join the dancers and creatives during Bangarra...
# 1  Justine Clarke takes a road trip into the hear...
# 2  Jessie Lloyd's Mission Songs Project revives s...
#
#                                         description2  \
# 0  In Yirrkala, Northeast Arnhem Land, Bangarra s...
# 1  Justine Clarke connects with some of Australia...
# 2  A song from the Torres Strait Islands, 'Surrar...
#
#                                                 tags  \
# 0  [ABC TV, ABC TV Plus, INDIGENOUS, ARTS & CULTU...
# 1  [ABC TV, DOCUMENTARY, ARTS & CULTURE, LIFESTYL...
# 2  [ABC TV, DOCUMENTARY, ARTS & CULTURE, INDIGENOUS]
#
#                                                image  \
# 0  https://cdn.iview.abc.net.au/thumbs/i/ar/AR194...
# 1  https://cdn.iview.abc.net.au/thumbs/i/ac/AC201...
# 2  https://cdn.iview.abc.net.au/thumbs/i/ip/IP206...
#
#                             directors_actors  \
# 0  [['Director Nel Minchin', 'Wayne Blair']]
# 1                  [['Host Justine Clarke']]
# 2                                       [[]]
#
#                                                tags2     publication_date  \
# 0  [abc1, abc2, indigenous, abcarts, arts, docs, ...  2021-07-07 22:00:00
# 1  [abc1, docs, arts, factual, lifestyle, country...  2021-11-02 20:30:14
# 2  [abc1, docs, factual, arts, indigenous, music,...  2020-11-07 07:00:00
#
#   rating  duration_sec season episode                 episode_title
# 0      G         626.0    NaN          Return to Country (Yirrkala)
# 1     PG        3244.0      1       1
# 2      G         313.0    NaN                               Surrare

# %%
# Write the concatenated data to a new file
if os.path.exists(directory_path + '/full_data.pkl'):
    os.remove(directory_path + '/full_data.pkl')

with open(directory_path + '/full_data.pkl', 'wb') as f:
    pickle.dump(clean, f)

# %%
films = clean.copy()

films = films[(films['series'].isna()) & (films['category'] != 'News') & (films['category'] != 'Panel Discussion')]

films = films.reset_index(drop = True)

films['id'] = films.index
cols = films.columns.tolist()
cols = cols[-1:] + cols[:-1]
films = films[cols]

films
# Out:
#                       episode_title   id category  \
# 0                        Ballet Now    0     Arts
# 1    Freddie Mercury: The Final Act    1     Arts
# 2                     Becoming Jane    2     Arts
# 3                              Pina    3     Arts
# 4                             Dyad     4     Arts
# ..                              ...  ...      ...
# 358                      Easy Rider  358   Movies
# 359                         Altered  359   Movies
# 360                       Let Me In  360   Movies
# 361          For Your Consideration  361   Movies
# 362                   All That Jazz  362   Movies
#
#                               title series                    episode_name  \
# 0                        Ballet Now    NaN                      Ballet Now
# 1    Freddie Mercury: The Final Act    NaN  Freddie Mercury: The Final Act
# 2                     Becoming Jane    NaN                   Becoming Jane
# 3                              Pina    NaN                            Pina
# 4                         Dyad 1929    NaN                       Dyad 1929
# ..                              ...    ...                             ...
# 358                      Easy Rider    NaN                      Easy Rider
# 359                         Altered    NaN                         Altered
# 360                       Let Me In    NaN                       Let Me In
# 361          For Your Consideration    NaN          For Your Consideration
# 362                   All That Jazz    NaN                   All That Jazz
#
#                                            description  \
# 0    This film captures the creative process behind...
# 1    The extraordinary story of Freddie Mercury's b...
# 2    When feisty, 20-year-old, budding novelist, Ja...
# 3    From the acclaimed filmmaker Wim Wenders, Pina...
# 4    Wayne McGregor's Dyad 1929, made on The Austra...
# ..                                                 ...
# 358  Chronicles the search for freedom by two motor...
# 359  From the writer-director of The Blair Witch Pr...
# 360  Bullied and lonley, 12-year-old Owen befriends...
# 361  When award rumours begin to circulate on the s...
# 362  The story of a gifted choreographer whose comp...
#
#                                           description2  \
# 0    This film captures the creative process behind...
# 1    The extraordinary story of Freddie Mercury's b...
# 2    When feisty, 20-year-old, budding novelist, Ja...
# 3    From the acclaimed filmmaker Wim Wenders, Pina...
# 4    Wayne McGregor's Dyad 1929, made on The Austra...
# ..                                                 ...
# 358  Chronicles the search for freedom by two motor...
# 359  From the writer-director of The Blair Witch Pr...
# 360  Bullied and lonley, 12-year-old Owen befriends...
# 361  When award rumours begin to circulate on the s...
# 362  The story of a gifted choreographer whose comp...
#
#                                                   tags  \
# 0    [ABC TV Plus, DOCUMENTARY, ARTS & CULTURE, FAM...
# 1                [ABC TV, DOCUMENTARY, ARTS & CULTURE]
# 2    [ABC TV, ABC TV Plus, DRAMA, ARTS & CULTURE, M...
# 3    [ABC TV, ABC TV Plus, ARTS & CULTURE, DOCUMENT...
# 4              [ABC TV Plus, ABC ARTS, ARTS & CULTURE]
# ..                                                 ...
# 358                      [ABC TV, ABC TV Plus, MOVIES]
# 359                      [ABC TV, ABC TV Plus, MOVIES]
# 360                      [ABC TV, ABC TV Plus, MOVIES]
# 361                      [ABC TV, ABC TV Plus, MOVIES]
# 362                      [ABC TV, ABC TV Plus, MOVIES]
#
#                                                  image  \
# 0    https://cdn.iview.abc.net.au/thumbs/i/zw/ZW269...
# 1    https://cdn.iview.abc.net.au/thumbs/i/zw/ZW324...
# 2    https://cdn.iview.abc.net.au/thumbs/i/zw/ZW284...
# 3    https://cdn.iview.abc.net.au/thumbs/i/zx/ZX958...
# 4    https://cdn.iview.abc.net.au/thumbs/i/zw/ZW297...
# ..                                                 ...
# 358  https://cdn.iview.abc.net.au/thumbs/i/zy/ZY933...
# 359  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW287...
# 360  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW290...
# 361  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW289...
# 362  https://cdn.iview.abc.net.au/thumbs/i/zy/ZY931...
#
#                                       directors_actors  \
# 0                                                 [[]]
# 1                                                 [[]]
# 2                        [['Director Julian Jarrold']]
# 3                           [['Director Wim Wenders']]
# 4                                                 [[]]
# ..                                                 ...
# 358                       [['Director Dennis Hopper']]
# 359                     [['Director Eduardo Sanchez']]
# 360  [['Cast Kodi Smit-McPhee', 'Chloe Grace Moretz...
# 361                   [['Director Christopher Guest']]
# 362                           [['Director Bob Fosse']]
#
#                                                  tags2     publication_date  \
# 0    [abc2, docs, factual, arts, ballet, dance, cul...  2021-06-30 21:59:27
# 1    [abc1, docs, arts, factual, culture, music, ro...  2022-03-15 20:31:03
# 2    [abc1, abc2, drama, period-drama, 1700s, arts,...  2021-06-01 07:00:00
# 3    [abc1, abc2, abcarts, arts, docs, factual, per...  2021-06-11 07:00:00
# 4    [abc2, arts, abcarts, ballet, entertainment, c...  2021-06-18 07:00:00
# ..                                                 ...                  ...
# 358  [abc1, abc2, film, usa, american, friendship, ...  2021-06-25 07:00:00
# 359  [abc1, abc2, usa, horror, thriller, sci-fi, su...  2021-06-01 07:00:00
# 360  [abc1, abc2, usa, uk, horror, supernatural, va...  2021-06-01 07:00:00
# 361  [abc1, abc2, comedy-drama, film, 1940s, americ...  2021-06-01 07:00:00
# 362  [abc1, abc2, film, musical, 1970s, music, a:es...  2021-06-25 07:00:00
#
#     rating  duration_sec season episode
# 0        M        3555.0    NaN
# 1        M        5377.0    NaN
# 2       PG        6915.0    NaN
# 3        G        5949.0    NaN
# 4        G        1586.0    NaN
# ..     ...           ...    ...     ...
# 358      M        5495.0    NaN
# 359     MA        5053.0    NaN
# 360     MA        6629.0    NaN
# 361      M        4927.0    NaN
# 362      M        7065.0    NaN
#
# [363 rows x 17 columns]

# %%
# Separating the films from the series
if os.path.exists(directory_path + '/full_movies.pkl'):
    os.remove(directory_path + '/full_movies.pkl')

with open(directory_path + '/full_movies.pkl', 'wb') as f:
    pickle.dump(films, f)

# %% [markdown]
# # Creating a new dataframe with only the series

# %%
series_raw = clean[(clean['series'].isna()==False)]

# assuming your original dataframe is called 'tv_series'
series_grouped = series_raw.groupby('title')

# create a new dataframe with the relevant information per TV series
series = pd.DataFrame({
    'category': series_grouped['category'].first(),
    'description': series_grouped['description'].first(),
    'description2': series_grouped['description2'].agg(list),
    'directors_actors': series_grouped['directors_actors'].sum().apply(set).apply(list),
    'publication_date': series_grouped['publication_date'].first(),
    'rating': series_grouped['rating'].first(),
    'duration_sec': series_grouped['duration_sec'].agg(list),
    'tags': series_grouped['tags'].first(),
    'tags2' : series_grouped['tags2'].sum().apply(set).apply(list),
    'image': series_grouped['image'].first()
})


series.reset_index(inplace = True)
series['id'] = series.index + 10_000
cols = series.columns.tolist()
cols = cols[-1:] + cols[:-1]
series = series[cols]

series
# Out:
#         id                                  title   category  \
# 0    10000                      199 Little Heroes  Education
# 1    10001                                   7.30       News
# 2    10002             7.30 Mark Humphries Satire       News
# 3    10003                   7.30: The Interviews       News
# 4    10004                      72 Cutest Animals     Family
# ..     ...                                    ...        ...
# 672  10672                         hoopla doopla!       Kids
# 673  10673              hoopla doopla! (Mandarin)  Education
# 674  10674                              storyTree  Education
# 675  10675                triple j Like A Version       Arts
# 676  10676  triple j's One Night Stand, Lucindale       Arts
#
#                                            description  \
# 0    The journey to school is a very special type o...
# 1    Leigh Sales presents Australia's leading night...
# 2    Satirist Mark Humphries brings his unique pers...
# 3    Revisit some of 7.30's most compelling convers...
# 4    The animal kingdom continually astounds us wit...
# ..                                                 ...
# 672  hoopla doopla! is a live action preschool show...
# 673  hoopla doopla! is a live action preschool show...
# 674  Join storyteller, Miss Treeleaf, in an imagina...
# 675  A popular segment recorded at triple j studios...
# 676  triple j takes the live music experience to a ...
#
#                                           description2 directors_actors  \
# 0    [Enjo lives in Quinten, a forest glade in the ...             [[]]
# 1    [The devastation caused by the recent floods i...             [[]]
# 2    [Satirist Mark Humphries goes inside the Healt...             [[]]
# 3    [Musician Dave Grohl sits down with 7.30's Lei...             [[]]
# 4    [Cute is a notion that can mean many things to...             [[]]
# ..                                                 ...              ...
# 672  [Jango dresses up as a king and his friends mi...             [[]]
# 673  [Jango is determined to be picked to be in the...             [[]]
# 674  [When little red hen bakes a cake, her lazy fr...             [[]]
# 675  [1300 cover Psy for Like A Version., A.GIRL co...             [[]]
# 676  [Hilltop Hoods live on stage with special gues...             [[]]
#
#         publication_date rating  \
# 0    2021-06-01 06:20:00      G
# 1    2022-03-14 20:00:00   None
# 2    2021-05-11 14:00:00   None
# 3    2022-03-08 20:00:00   None
# 4    2022-03-05 15:03:06      G
# ..                   ...    ...
# 672  2022-01-28 06:15:10      G
# 673  2022-01-28 06:35:20      G
# 674  2020-03-20 14:11:00      G
# 675  2022-03-18 18:00:00      M
# 676  2019-09-16 17:00:00      M
#
#                                           duration_sec  \
# 0    [311.0, 311.0, 312.0, 311.0, 311.0, 320.0, 311...
# 1    [1906.0, 1894.0, 1879.0, 1935.0, 1891.0, 1822....
# 2    [145.0, 110.0, 118.0, 136.0, 202.0, 115.0, 241...
# 3                                             [1030.0]
# 4    [1616.0, 1616.0, 1620.0, 1620.0, 1614.0, 1620....
# ..                                                 ...
# 672  [720.0, 720.0, 720.0, 720.0, 720.0, 720.0, 720...
# 673  [720.0, 720.0, 720.0, 720.0, 720.0, 720.0, 720...
# 674  [210.0, 210.0, 210.0, 210.0, 210.0, 210.0, 210...
# 675                [395.0, 407.0, 470.0, 238.0, 467.0]
# 676            [3873.0, 507.0, 2208.0, 2372.0, 2665.0]
#
#                                         tags  \
# 0                        [ABC ME, EDUCATION]
# 1                         [ABC TV, ABC NEWS]
# 2                                 [ABC NEWS]
# 3                                 [ABC NEWS]
# 4                           [ABC ME, FAMILY]
# ..                                       ...
# 672                               [ABC Kids]
# 673                               [ABC Kids]
# 674                    [ABC Kids, EDUCATION]
# 675                 [ABC TV, ARTS & CULTURE]
# 676  [ABC ARTS, ABC TV Plus, ARTS & CULTURE]
#
#                                                  tags2  \
# 0    [abc3, primary-humanities, environment-day, re...
# 1    [budget, economy, 730, abc-faves, covid-19, ne...
# 2    [mark, ley, satire, humphries, care, duty, of,...
# 3                                       [news24, news]
# 4         [abc3, family-viewing-abcme, family-viewing]
# ..                                                 ...
# 672  [abc4kids, 4movers, 4imagine, 4best, ps-birthd...
# 673        [4liveaction, abc4kids, forever, education]
# 674  [primary-english, abc4kids, education, 4story,...
# 675  [aussie, live-music, iview, ausmusic, rock-n-r...
# 676  [triplej, abcarts, latest, performance, music,...
#
#                                                  image
# 0    https://cdn.iview.abc.net.au/thumbs/i/zw/ZW073...
# 1    https://cdn.iview.abc.net.au/thumbs/i/nc/NC220...
# 2    https://cdn.iview.abc.net.au/thumbs/i/nn/NN211...
# 3    https://cdn.iview.abc.net.au/thumbs/i/ns/NS224...
# 4    https://cdn.iview.abc.net.au/thumbs/i/zw/ZW243...
# ..                                                 ...
# 672  https://cdn.iview.abc.net.au/thumbs/i/ch/CH121...
# 673  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW103...
# 674  https://cdn.iview.abc.net.au/thumbs/i/zx/ZX941...
# 675  https://cdn.iview.abc.net.au/thumbs/i/iv/IV220...
# 676  https://cdn.iview.abc.net.au/thumbs/i/rk/RK190...
#
# [677 rows x 12 columns]

# %%
# Write the concatenated data to a new file
if os.path.exists(directory_path + '/full_shows.pkl'):
    os.remove(directory_path + '/full_shows.pkl')

with open(directory_path + '/full_shows.pkl', 'wb') as f:
    pickle.dump(series, f)

# %%
pd.

# %%
pd.read_pickle(directory_path + '/full_shows.pkl')
# Out:
#         id                                  title   category  \
# 0    10000                      199 Little Heroes  Education
# 1    10001                                   7.30       News
# 2    10002             7.30 Mark Humphries Satire       News
# 3    10003                   7.30: The Interviews       News
# 4    10004                      72 Cutest Animals     Family
# ..     ...                                    ...        ...
# 672  10672                         hoopla doopla!       Kids
# 673  10673              hoopla doopla! (Mandarin)  Education
# 674  10674                              storyTree  Education
# 675  10675                triple j Like A Version       Arts
# 676  10676  triple j's One Night Stand, Lucindale       Arts
#
#                                            description  \
# 0    The journey to school is a very special type o...
# 1    Leigh Sales presents Australia's leading night...
# 2    Satirist Mark Humphries brings his unique pers...
# 3    Revisit some of 7.30's most compelling convers...
# 4    The animal kingdom continually astounds us wit...
# ..                                                 ...
# 672  hoopla doopla! is a live action preschool show...
# 673  hoopla doopla! is a live action preschool show...
# 674  Join storyteller, Miss Treeleaf, in an imagina...
# 675  A popular segment recorded at triple j studios...
# 676  triple j takes the live music experience to a ...
#
#                                           description2 directors_actors  \
# 0    [Enjo lives in Quinten, a forest glade in the ...             [[]]
# 1    [The devastation caused by the recent floods i...             [[]]
# 2    [Satirist Mark Humphries goes inside the Healt...             [[]]
# 3    [Musician Dave Grohl sits down with 7.30's Lei...             [[]]
# 4    [Cute is a notion that can mean many things to...             [[]]
# ..                                                 ...              ...
# 672  [Jango dresses up as a king and his friends mi...             [[]]
# 673  [Jango is determined to be picked to be in the...             [[]]
# 674  [When little red hen bakes a cake, her lazy fr...             [[]]
# 675  [1300 cover Psy for Like A Version., A.GIRL co...             [[]]
# 676  [Hilltop Hoods live on stage with special gues...             [[]]
#
#         publication_date rating  \
# 0    2021-06-01 06:20:00      G
# 1    2022-03-14 20:00:00   None
# 2    2021-05-11 14:00:00   None
# 3    2022-03-08 20:00:00   None
# 4    2022-03-05 15:03:06      G
# ..                   ...    ...
# 672  2022-01-28 06:15:10      G
# 673  2022-01-28 06:35:20      G
# 674  2020-03-20 14:11:00      G
# 675  2022-03-18 18:00:00      M
# 676  2019-09-16 17:00:00      M
#
#                                           duration_sec  \
# 0    [311.0, 311.0, 312.0, 311.0, 311.0, 320.0, 311...
# 1    [1906.0, 1894.0, 1879.0, 1935.0, 1891.0, 1822....
# 2    [145.0, 110.0, 118.0, 136.0, 202.0, 115.0, 241...
# 3                                             [1030.0]
# 4    [1616.0, 1616.0, 1620.0, 1620.0, 1614.0, 1620....
# ..                                                 ...
# 672  [720.0, 720.0, 720.0, 720.0, 720.0, 720.0, 720...
# 673  [720.0, 720.0, 720.0, 720.0, 720.0, 720.0, 720...
# 674  [210.0, 210.0, 210.0, 210.0, 210.0, 210.0, 210...
# 675                [395.0, 407.0, 470.0, 238.0, 467.0]
# 676            [3873.0, 507.0, 2208.0, 2372.0, 2665.0]
#
#                                         tags  \
# 0                        [ABC ME, EDUCATION]
# 1                         [ABC TV, ABC NEWS]
# 2                                 [ABC NEWS]
# 3                                 [ABC NEWS]
# 4                           [ABC ME, FAMILY]
# ..                                       ...
# 672                               [ABC Kids]
# 673                               [ABC Kids]
# 674                    [ABC Kids, EDUCATION]
# 675                 [ABC TV, ARTS & CULTURE]
# 676  [ABC ARTS, ABC TV Plus, ARTS & CULTURE]
#
#                                                  tags2  \
# 0    [abc3, primary-humanities, environment-day, re...
# 1    [budget, economy, 730, abc-faves, covid-19, ne...
# 2    [mark, ley, satire, humphries, care, duty, of,...
# 3                                       [news24, news]
# 4         [abc3, family-viewing-abcme, family-viewing]
# ..                                                 ...
# 672  [abc4kids, 4movers, 4imagine, 4best, ps-birthd...
# 673        [4liveaction, abc4kids, forever, education]
# 674  [primary-english, abc4kids, education, 4story,...
# 675  [aussie, live-music, iview, ausmusic, rock-n-r...
# 676  [triplej, abcarts, latest, performance, music,...
#
#                                                  image
# 0    https://cdn.iview.abc.net.au/thumbs/i/zw/ZW073...
# 1    https://cdn.iview.abc.net.au/thumbs/i/nc/NC220...
# 2    https://cdn.iview.abc.net.au/thumbs/i/nn/NN211...
# 3    https://cdn.iview.abc.net.au/thumbs/i/ns/NS224...
# 4    https://cdn.iview.abc.net.au/thumbs/i/zw/ZW243...
# ..                                                 ...
# 672  https://cdn.iview.abc.net.au/thumbs/i/ch/CH121...
# 673  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW103...
# 674  https://cdn.iview.abc.net.au/thumbs/i/zx/ZX941...
# 675  https://cdn.iview.abc.net.au/thumbs/i/iv/IV220...
# 676  https://cdn.iview.abc.net.au/thumbs/i/rk/RK190...
#
# [677 rows x 12 columns]

# %%
pd.read_pickle(directory_path + '/full_movies.pkl')
# Out:
#                       episode_title   id category  \
# 0                        Ballet Now    0     Arts
# 1    Freddie Mercury: The Final Act    1     Arts
# 2                     Becoming Jane    2     Arts
# 3                              Pina    3     Arts
# 4                             Dyad     4     Arts
# ..                              ...  ...      ...
# 358                      Easy Rider  358   Movies
# 359                         Altered  359   Movies
# 360                       Let Me In  360   Movies
# 361          For Your Consideration  361   Movies
# 362                   All That Jazz  362   Movies
#
#                               title series                    episode_name  \
# 0                        Ballet Now    NaN                      Ballet Now
# 1    Freddie Mercury: The Final Act    NaN  Freddie Mercury: The Final Act
# 2                     Becoming Jane    NaN                   Becoming Jane
# 3                              Pina    NaN                            Pina
# 4                         Dyad 1929    NaN                       Dyad 1929
# ..                              ...    ...                             ...
# 358                      Easy Rider    NaN                      Easy Rider
# 359                         Altered    NaN                         Altered
# 360                       Let Me In    NaN                       Let Me In
# 361          For Your Consideration    NaN          For Your Consideration
# 362                   All That Jazz    NaN                   All That Jazz
#
#                                            description  \
# 0    This film captures the creative process behind...
# 1    The extraordinary story of Freddie Mercury's b...
# 2    When feisty, 20-year-old, budding novelist, Ja...
# 3    From the acclaimed filmmaker Wim Wenders, Pina...
# 4    Wayne McGregor's Dyad 1929, made on The Austra...
# ..                                                 ...
# 358  Chronicles the search for freedom by two motor...
# 359  From the writer-director of The Blair Witch Pr...
# 360  Bullied and lonley, 12-year-old Owen befriends...
# 361  When award rumours begin to circulate on the s...
# 362  The story of a gifted choreographer whose comp...
#
#                                           description2  \
# 0    This film captures the creative process behind...
# 1    The extraordinary story of Freddie Mercury's b...
# 2    When feisty, 20-year-old, budding novelist, Ja...
# 3    From the acclaimed filmmaker Wim Wenders, Pina...
# 4    Wayne McGregor's Dyad 1929, made on The Austra...
# ..                                                 ...
# 358  Chronicles the search for freedom by two motor...
# 359  From the writer-director of The Blair Witch Pr...
# 360  Bullied and lonley, 12-year-old Owen befriends...
# 361  When award rumours begin to circulate on the s...
# 362  The story of a gifted choreographer whose comp...
#
#                                                   tags  \
# 0    [ABC TV Plus, DOCUMENTARY, ARTS & CULTURE, FAM...
# 1                [ABC TV, DOCUMENTARY, ARTS & CULTURE]
# 2    [ABC TV, ABC TV Plus, DRAMA, ARTS & CULTURE, M...
# 3    [ABC TV, ABC TV Plus, ARTS & CULTURE, DOCUMENT...
# 4              [ABC TV Plus, ABC ARTS, ARTS & CULTURE]
# ..                                                 ...
# 358                      [ABC TV, ABC TV Plus, MOVIES]
# 359                      [ABC TV, ABC TV Plus, MOVIES]
# 360                      [ABC TV, ABC TV Plus, MOVIES]
# 361                      [ABC TV, ABC TV Plus, MOVIES]
# 362                      [ABC TV, ABC TV Plus, MOVIES]
#
#                                                  image  \
# 0    https://cdn.iview.abc.net.au/thumbs/i/zw/ZW269...
# 1    https://cdn.iview.abc.net.au/thumbs/i/zw/ZW324...
# 2    https://cdn.iview.abc.net.au/thumbs/i/zw/ZW284...
# 3    https://cdn.iview.abc.net.au/thumbs/i/zx/ZX958...
# 4    https://cdn.iview.abc.net.au/thumbs/i/zw/ZW297...
# ..                                                 ...
# 358  https://cdn.iview.abc.net.au/thumbs/i/zy/ZY933...
# 359  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW287...
# 360  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW290...
# 361  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW289...
# 362  https://cdn.iview.abc.net.au/thumbs/i/zy/ZY931...
#
#                                       directors_actors  \
# 0                                                 [[]]
# 1                                                 [[]]
# 2                        [['Director Julian Jarrold']]
# 3                           [['Director Wim Wenders']]
# 4                                                 [[]]
# ..                                                 ...
# 358                       [['Director Dennis Hopper']]
# 359                     [['Director Eduardo Sanchez']]
# 360  [['Cast Kodi Smit-McPhee', 'Chloe Grace Moretz...
# 361                   [['Director Christopher Guest']]
# 362                           [['Director Bob Fosse']]
#
#                                                  tags2     publication_date  \
# 0    [abc2, docs, factual, arts, ballet, dance, cul...  2021-06-30 21:59:27
# 1    [abc1, docs, arts, factual, culture, music, ro...  2022-03-15 20:31:03
# 2    [abc1, abc2, drama, period-drama, 1700s, arts,...  2021-06-01 07:00:00
# 3    [abc1, abc2, abcarts, arts, docs, factual, per...  2021-06-11 07:00:00
# 4    [abc2, arts, abcarts, ballet, entertainment, c...  2021-06-18 07:00:00
# ..                                                 ...                  ...
# 358  [abc1, abc2, film, usa, american, friendship, ...  2021-06-25 07:00:00
# 359  [abc1, abc2, usa, horror, thriller, sci-fi, su...  2021-06-01 07:00:00
# 360  [abc1, abc2, usa, uk, horror, supernatural, va...  2021-06-01 07:00:00
# 361  [abc1, abc2, comedy-drama, film, 1940s, americ...  2021-06-01 07:00:00
# 362  [abc1, abc2, film, musical, 1970s, music, a:es...  2021-06-25 07:00:00
#
#     rating  duration_sec season episode
# 0        M        3555.0    NaN
# 1        M        5377.0    NaN
# 2       PG        6915.0    NaN
# 3        G        5949.0    NaN
# 4        G        1586.0    NaN
# ..     ...           ...    ...     ...
# 358      M        5495.0    NaN
# 359     MA        5053.0    NaN
# 360     MA        6629.0    NaN
# 361      M        4927.0    NaN
# 362      M        7065.0    NaN
#
# [363 rows x 17 columns]
